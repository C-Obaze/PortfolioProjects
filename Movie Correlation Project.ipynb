# %%
#import libraries

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) #Adjusts the configuration of the plot created

#Read the data

df = pd.read_csv(r"C:\Users\USER\Documents\movies.csv")

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime
# 0   46998772.0        Warner Bros.    146.0
# 1   58853106.0   Columbia Pictures    104.0
# 2  538375067.0           Lucasfilm    124.0
# 3   83453539.0  Paramount Pictures     88.0
# 4   39846344.0      Orion Pictures     98.0

# %%
#check for missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
#check data types

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df['votes'] = df['votes'].astype('Int64')
df['runtime'] = df['runtime'].astype('Int64')

# %%
#formatting dataframe-released column to exclude the country

df['released'] = df['released'].str.extract(r'(\w+ \d+, \d+)', expand=False)

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#         released  score    votes         director                   writer  \
# 0  June 13, 1980    8.4   927000  Stanley Kubrick             Stephen King
# 1   July 2, 1980    5.8    65000   Randal Kleiser  Henry De Vere Stacpoole
# 2  June 20, 1980    8.7  1200000   Irvin Kershner           Leigh Brackett
# 3   July 2, 1980    7.7   221000     Jim Abrahams             Jim Abrahams
# 4  July 25, 1980    7.3   108000     Harold Ramis       Brian Doyle-Murray
#
#              star         country      budget        gross  \
# 0  Jack Nicholson  United Kingdom  19000000.0   46998772.0
# 1  Brooke Shields   United States   4500000.0   58853106.0
# 2     Mark Hamill   United States  18000000.0  538375067.0
# 3     Robert Hays   United States   3500000.0   83453539.0
# 4     Chevy Chase   United States   6000000.0   39846344.0
#
#               company  runtime
# 0        Warner Bros.      146
# 1   Columbia Pictures      104
# 2           Lucasfilm      124
# 3  Paramount Pictures       88
# 4      Orion Pictures       98

# %%
df['released'] = pd.to_datetime(df['released'], format="%B %d, %Y")

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#     released  score    votes         director                   writer  \
# 0 1980-06-13    8.4   927000  Stanley Kubrick             Stephen King
# 1 1980-07-02    5.8    65000   Randal Kleiser  Henry De Vere Stacpoole
# 2 1980-06-20    8.7  1200000   Irvin Kershner           Leigh Brackett
# 3 1980-07-02    7.7   221000     Jim Abrahams             Jim Abrahams
# 4 1980-07-25    7.3   108000     Harold Ramis       Brian Doyle-Murray
#
#              star         country      budget        gross  \
# 0  Jack Nicholson  United Kingdom  19000000.0   46998772.0
# 1  Brooke Shields   United States   4500000.0   58853106.0
# 2     Mark Hamill   United States  18000000.0  538375067.0
# 3     Robert Hays   United States   3500000.0   83453539.0
# 4     Chevy Chase   United States   6000000.0   39846344.0
#
#               company  runtime
# 0        Warner Bros.      146
# 1   Columbia Pictures      104
# 2           Lucasfilm      124
# 3  Paramount Pictures       88
# 4      Orion Pictures       98

# %%
df['yearcorrect'] = df['released'].astype(str).str[:4]

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#     released  score    votes         director                   writer  \
# 0 1980-06-13    8.4   927000  Stanley Kubrick             Stephen King
# 1 1980-07-02    5.8    65000   Randal Kleiser  Henry De Vere Stacpoole
# 2 1980-06-20    8.7  1200000   Irvin Kershner           Leigh Brackett
# 3 1980-07-02    7.7   221000     Jim Abrahams             Jim Abrahams
# 4 1980-07-25    7.3   108000     Harold Ramis       Brian Doyle-Murray
#
#              star         country      budget        gross  \
# 0  Jack Nicholson  United Kingdom  19000000.0   46998772.0
# 1  Brooke Shields   United States   4500000.0   58853106.0
# 2     Mark Hamill   United States  18000000.0  538375067.0
# 3     Robert Hays   United States   3500000.0   83453539.0
# 4     Chevy Chase   United States   6000000.0   39846344.0
#
#               company  runtime yearcorrect
# 0        Warner Bros.      146        1980
# 1   Columbia Pictures      104        1980
# 2           Lucasfilm      124        1980
# 3  Paramount Pictures       88        1980
# 4      Orion Pictures       98        1980

# %%
df = df.sort_values(by=['gross'], inplace=False, ascending=False)

# %%
df.head()
# Out:
#       name  rating  genre  year   released  score    votes  director  writer  \
# 5445   533       5      0  2009 2009-12-18    7.8  1100000      1155    1778
# 7445   535       5      0  2019 2019-04-26    8.4   903000       162     743
# 3045  6896       5      6  1997 1997-12-19    7.8  1100000      1155    1778
# 6663  5144       5      0  2015 2015-12-18    7.8   876000      1125    2550
# 7244   536       5      0  2018 2018-04-27    8.4   897000       162     743
#
#       star  country       budget         gross  company  runtime  yearcorrect
# 5445  2334       55  237000000.0  2.847246e+09     2253      162           29
# 7445  2241       55  356000000.0  2.797501e+09     1606      181           39
# 3045  1595       55  200000000.0  2.201647e+09     2253      194           17
# 6663   524       55  245000000.0  2.069522e+09     1540      138           35
# 7244  2241       55  321000000.0  2.048360e+09     1606      149           38

# %%
plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Budget for Film')
plt.ylabel('Gross Earnings')
plt.show()

# %%
#plot budget vs gross using seaborn

sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color': 'green'}, line_kws={'color': 'blue'})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
df.corr()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_21752\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
correlation_matrix = df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation matrix for numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_21752\3010219160.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr(method='pearson')
# Text(120.72222222222221, 0.5, 'Movie Features')

# %%
df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes

# %%
df_numerized.head()
# Out:
#       name  rating  genre  year   released  score    votes  director  writer  \
# 5445   533       5      0  2009 2009-12-18    7.8  1100000      1155    1778
# 7445   535       5      0  2019 2019-04-26    8.4   903000       162     743
# 3045  6896       5      6  1997 1997-12-19    7.8  1100000      1155    1778
# 6663  5144       5      0  2015 2015-12-18    7.8   876000      1125    2550
# 7244   536       5      0  2018 2018-04-27    8.4   897000       162     743
#
#       star  country       budget         gross  company  runtime  yearcorrect
# 5445  2334       55  237000000.0  2.847246e+09     2253      162           29
# 7445  2241       55  356000000.0  2.797501e+09     1606      181           39
# 3045  1595       55  200000000.0  2.201647e+09     2253      194           17
# 6663   524       55  245000000.0  2.069522e+09     1540      138           35
# 7244  2241       55  321000000.0  2.048360e+09     1606      149           38

# %%
df.head()
# Out:
#       name  rating  genre  year   released  score    votes  director  writer  \
# 5445   533       5      0  2009 2009-12-18    7.8  1100000      1155    1778
# 7445   535       5      0  2019 2019-04-26    8.4   903000       162     743
# 3045  6896       5      6  1997 1997-12-19    7.8  1100000      1155    1778
# 6663  5144       5      0  2015 2015-12-18    7.8   876000      1125    2550
# 7244   536       5      0  2018 2018-04-27    8.4   897000       162     743
#
#       star  country       budget         gross  company  runtime  yearcorrect
# 5445  2334       55  237000000.0  2.847246e+09     2253      162           29
# 7445  2241       55  356000000.0  2.797501e+09     1606      181           39
# 3045  1595       55  200000000.0  2.201647e+09     2253      194           17
# 6663   524       55  245000000.0  2.069522e+09     1540      138           35
# 7244  2241       55  321000000.0  2.048360e+09     1606      149           38

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#        released  score    votes       director              writer  \
# 5445 2009-12-18    7.8  1100000  James Cameron       James Cameron
# 7445 2019-04-26    8.4   903000  Anthony Russo  Christopher Markus
# 3045 1997-12-19    7.8  1100000  James Cameron       James Cameron
# 6663 2015-12-18    7.8   876000    J.J. Abrams     Lawrence Kasdan
# 7244 2018-04-27    8.4   897000  Anthony Russo  Christopher Markus
#
#                    star        country       budget         gross  \
# 5445    Sam Worthington  United States  237000000.0  2.847246e+09
# 7445  Robert Downey Jr.  United States  356000000.0  2.797501e+09
# 3045  Leonardo DiCaprio  United States  200000000.0  2.201647e+09
# 6663       Daisy Ridley  United States  245000000.0  2.069522e+09
# 7244  Robert Downey Jr.  United States  321000000.0  2.048360e+09
#
#                     company  runtime yearcorrect
# 5445  Twentieth Century Fox      162        2009
# 7445         Marvel Studios      181        2019
# 3045  Twentieth Century Fox      194        1997
# 6663              Lucasfilm      138        2015
# 7244         Marvel Studios      149        2018

# %%
correlation_matrix = df_numerized.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation matrix for numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_21752\4111034738.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df_numerized.corr(method='pearson')
# Text(120.72222222222221, 0.5, 'Movie Features')

# %%
df_numerized.corr()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_21752\1284351489.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_numerized.corr()
#                  name    rating     genre      year     score     votes  \
# name         1.000000 -0.008069  0.016355  0.011453  0.017097  0.013088
# rating      -0.008069  1.000000  0.072423  0.008779 -0.001314  0.033225
# genre        0.016355  0.072423  1.000000 -0.081261  0.027965 -0.145307
# year         0.011453  0.008779 -0.081261  1.000000  0.097995  0.222945
# score        0.017097 -0.001314  0.027965  0.097995  1.000000  0.409182
# votes        0.013088  0.033225 -0.145307  0.222945  0.409182  1.000000
# director     0.009079  0.019483 -0.015258 -0.020795  0.009559  0.000260
# writer       0.009081 -0.005921  0.006567 -0.008656  0.019416  0.000892
# star         0.006472  0.013405 -0.005477 -0.027242 -0.001609 -0.019282
# country     -0.010737  0.081244 -0.037615 -0.070938 -0.133348  0.073625
# budget       0.023970 -0.176002 -0.356564  0.329321  0.076254  0.442429
# gross        0.005533 -0.107339 -0.235650  0.257486  0.186258  0.630757
# company      0.009211 -0.032943 -0.071067 -0.010431  0.001030  0.133204
# runtime      0.010392  0.062145 -0.052711  0.120811  0.399451  0.309212
# yearcorrect  0.012835  0.009280 -0.063573  0.967486  0.107219  0.206475
#
#              director    writer      star   country    budget     gross  \
# name         0.009079  0.009081  0.006472 -0.010737  0.023970  0.005533
# rating       0.019483 -0.005921  0.013405  0.081244 -0.176002 -0.107339
# genre       -0.015258  0.006567 -0.005477 -0.037615 -0.356564 -0.235650
# year        -0.020795 -0.008656 -0.027242 -0.070938  0.329321  0.257486
# score        0.009559  0.019416 -0.001609 -0.133348  0.076254  0.186258
# votes        0.000260  0.000892 -0.019282  0.073625  0.442429  0.630757
# director     1.000000  0.299067  0.039234  0.017490 -0.012272 -0.014441
# writer       0.299067  1.000000  0.027245  0.015343 -0.039451 -0.023519
# star         0.039234  0.027245  1.000000 -0.012998 -0.019589 -0.002717
# country      0.017490  0.015343 -0.012998  1.000000  0.054063  0.092129
# budget      -0.012272 -0.039451 -0.019589  0.054063  1.000000  0.740395
# gross       -0.014441 -0.023519 -0.002717  0.092129  0.740395  1.000000
# company      0.004404  0.005646  0.012442  0.095548  0.173214  0.154840
# runtime      0.017624 -0.003511  0.010174 -0.078412  0.320447  0.245216
# yearcorrect -0.022579 -0.010063 -0.031166 -0.090962  0.315348  0.240651
#
#               company   runtime  yearcorrect
# name         0.009211  0.010392     0.012835
# rating      -0.032943  0.062145     0.009280
# genre       -0.071067 -0.052711    -0.063573
# year        -0.010431  0.120811     0.967486
# score        0.001030  0.399451     0.107219
# votes        0.133204  0.309212     0.206475
# director     0.004404  0.017624    -0.022579
# writer       0.005646 -0.003511    -0.010063
# star         0.012442  0.010174    -0.031166
# country      0.095548 -0.078412    -0.090962
# budget       0.173214  0.320447     0.315348
# gross        0.154840  0.245216     0.240651
# company      1.000000  0.034402    -0.026492
# runtime      0.034402  1.000000     0.115317
# yearcorrect -0.026492  0.115317     1.000000

# %%
correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_21752\1290311030.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_mat = df_numerized.corr()
# name         name           1.000000
#              rating        -0.008069
#              genre          0.016355
#              year           0.011453
#              score          0.017097
#              votes          0.013088
#              director       0.009079
#              writer         0.009081
#              star           0.006472
#              country       -0.010737
#              budget         0.023970
#              gross          0.005533
#              company        0.009211
#              runtime        0.010392
#              yearcorrect    0.012835
# rating       name          -0.008069
#              rating         1.000000
#              genre          0.072423
#              year           0.008779
#              score         -0.001314
#              votes          0.033225
#              director       0.019483
#              writer        -0.005921
#              star           0.013405
#              country        0.081244
#              budget        -0.176002
#              gross         -0.107339
#              company       -0.032943
#              runtime        0.062145
#              yearcorrect    0.009280
# genre        name           0.016355
#              rating         0.072423
#              genre          1.000000
#              year          -0.081261
#              score          0.027965
#              votes         -0.145307
#              director      -0.015258
#              writer         0.006567
#              star          -0.005477
#              country       -0.037615
#              budget        -0.356564
#              gross         -0.235650
#              company       -0.071067
#              runtime       -0.052711
#              yearcorrect   -0.063573
# year         name           0.011453
#              rating         0.008779
#              genre         -0.081261
#              year           1.000000
#              score          0.097995
#              votes          0.222945
#              director      -0.020795
#              writer        -0.008656
#              star          -0.027242
#              country       -0.070938
#              budget         0.329321
#              gross          0.257486
#              company       -0.010431
#              runtime        0.120811
#              yearcorrect    0.967486
# score        name           0.017097
#              rating        -0.001314
#              genre          0.027965
#              year           0.097995
#              score          1.000000
#              votes          0.409182
#              director       0.009559
#              writer         0.019416
#              star          -0.001609
#              country       -0.133348
#              budget         0.076254
#              gross          0.186258
#              company        0.001030
#              runtime        0.399451
#              yearcorrect    0.107219
# votes        name           0.013088
#              rating         0.033225
#              genre         -0.145307
#              year           0.222945
#              score          0.409182
#              votes          1.000000
#              director       0.000260
#              writer         0.000892
#              star          -0.019282
#              country        0.073625
#              budget         0.442429
#              gross          0.630757
#              company        0.133204
#              runtime        0.309212
#              yearcorrect    0.206475
# director     name           0.009079
#              rating         0.019483
#              genre         -0.015258
#              year          -0.020795
#              score          0.009559
#              votes          0.000260
#              director       1.000000
#              writer         0.299067
#              star           0.039234
#              country        0.017490
#              budget        -0.012272
#              gross         -0.014441
#              company        0.004404
#              runtime        0.017624
#              yearcorrect   -0.022579
# writer       name           0.009081
#              rating        -0.005921
#              genre          0.006567
#              year          -0.008656
#              score          0.019416
#              votes          0.000892
#              director       0.299067
#              writer         1.000000
#              star           0.027245
#              country        0.015343
#              budget        -0.039451
#              gross         -0.023519
#              company        0.005646
#              runtime       -0.003511
#              yearcorrect   -0.010063
# star         name           0.006472
#              rating         0.013405
#              genre         -0.005477
#              year          -0.027242
#              score         -0.001609
#              votes         -0.019282
#              director       0.039234
#              writer         0.027245
#              star           1.000000
#              country       -0.012998
#              budget        -0.019589
#              gross         -0.002717
#              company        0.012442
#              runtime        0.010174
#              yearcorrect   -0.031166
# country      name          -0.010737
#              rating         0.081244
#              genre         -0.037615
#              year          -0.070938
#              score         -0.133348
#              votes          0.073625
#              director       0.017490
#              writer         0.015343
#              star          -0.012998
#              country        1.000000
#              budget         0.054063
#              gross          0.092129
#              company        0.095548
#              runtime       -0.078412
#              yearcorrect   -0.090962
# budget       name           0.023970
#              rating        -0.176002
#              genre         -0.356564
#              year           0.329321
#              score          0.076254
#              votes          0.442429
#              director      -0.012272
#              writer        -0.039451
#              star          -0.019589
#              country        0.054063
#              budget         1.000000
#              gross          0.740395
#              company        0.173214
#              runtime        0.320447
#              yearcorrect    0.315348
# gross        name           0.005533
#              rating        -0.107339
#              genre         -0.235650
#              year           0.257486
#              score          0.186258
#              votes          0.630757
#              director      -0.014441
#              writer        -0.023519
#              star          -0.002717
#              country        0.092129
#              budget         0.740395
#              gross          1.000000
#              company        0.154840
#              runtime        0.245216
#              yearcorrect    0.240651
# company      name           0.009211
#              rating        -0.032943
#              genre         -0.071067
#              year          -0.010431
#              score          0.001030
#              votes          0.133204
#              director       0.004404
#              writer         0.005646
#              star           0.012442
#              country        0.095548
#              budget         0.173214
#              gross          0.154840
#              company        1.000000
#              runtime        0.034402
#              yearcorrect   -0.026492
# runtime      name           0.010392
#              rating         0.062145
#              genre         -0.052711
#              year           0.120811
#              score          0.399451
#              votes          0.309212
#              director       0.017624
#              writer        -0.003511
#              star           0.010174
#              country       -0.078412
#              budget         0.320447
#              gross          0.245216
#              company        0.034402
#              runtime        1.000000
#              yearcorrect    0.115317
# yearcorrect  name           0.012835
#              rating         0.009280
#              genre         -0.063573
#              year           0.967486
#              score          0.107219
#              votes          0.206475
#              director      -0.022579
#              writer        -0.010063
#              star          -0.031166
#              country       -0.090962
#              budget         0.315348
#              gross          0.240651
#              company       -0.026492
#              runtime        0.115317
#              yearcorrect    1.000000
# dtype: float64

# %%
pd.set_option('display.max_rows', None)

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# genre        budget        -0.356564
# budget       genre         -0.356564
# gross        genre         -0.235650
# genre        gross         -0.235650
# rating       budget        -0.176002
# budget       rating        -0.176002
# votes        genre         -0.145307
# genre        votes         -0.145307
# country      score         -0.133348
# score        country       -0.133348
# gross        rating        -0.107339
# rating       gross         -0.107339
# yearcorrect  country       -0.090962
# country      yearcorrect   -0.090962
# year         genre         -0.081261
# genre        year          -0.081261
# country      runtime       -0.078412
# runtime      country       -0.078412
# genre        company       -0.071067
# company      genre         -0.071067
# country      year          -0.070938
# year         country       -0.070938
# genre        yearcorrect   -0.063573
# yearcorrect  genre         -0.063573
# runtime      genre         -0.052711
# genre        runtime       -0.052711
# budget       writer        -0.039451
# writer       budget        -0.039451
# country      genre         -0.037615
# genre        country       -0.037615
# rating       company       -0.032943
# company      rating        -0.032943
# yearcorrect  star          -0.031166
# star         yearcorrect   -0.031166
# year         star          -0.027242
# star         year          -0.027242
# yearcorrect  company       -0.026492
# company      yearcorrect   -0.026492
# gross        writer        -0.023519
# writer       gross         -0.023519
# yearcorrect  director      -0.022579
# director     yearcorrect   -0.022579
# year         director      -0.020795
# director     year          -0.020795
# star         budget        -0.019589
# budget       star          -0.019589
# star         votes         -0.019282
# votes        star          -0.019282
# director     genre         -0.015258
# genre        director      -0.015258
# gross        director      -0.014441
# director     gross         -0.014441
# country      star          -0.012998
# star         country       -0.012998
# director     budget        -0.012272
# budget       director      -0.012272
# name         country       -0.010737
# country      name          -0.010737
# company      year          -0.010431
# year         company       -0.010431
# writer       yearcorrect   -0.010063
# yearcorrect  writer        -0.010063
# writer       year          -0.008656
# year         writer        -0.008656
# name         rating        -0.008069
# rating       name          -0.008069
#              writer        -0.005921
# writer       rating        -0.005921
# star         genre         -0.005477
# genre        star          -0.005477
# runtime      writer        -0.003511
# writer       runtime       -0.003511
# gross        star          -0.002717
# star         gross         -0.002717
#              score         -0.001609
# score        star          -0.001609
# rating       score         -0.001314
# score        rating        -0.001314
# votes        director       0.000260
# director     votes          0.000260
# votes        writer         0.000892
# writer       votes          0.000892
# company      score          0.001030
# score        company        0.001030
# director     company        0.004404
# company      director       0.004404
# name         gross          0.005533
# gross        name           0.005533
# company      writer         0.005646
# writer       company        0.005646
# star         name           0.006472
# name         star           0.006472
# writer       genre          0.006567
# genre        writer         0.006567
# year         rating         0.008779
# rating       year           0.008779
# name         director       0.009079
# director     name           0.009079
# name         writer         0.009081
# writer       name           0.009081
# company      name           0.009211
# name         company        0.009211
# yearcorrect  rating         0.009280
# rating       yearcorrect    0.009280
# score        director       0.009559
# director     score          0.009559
# runtime      star           0.010174
# star         runtime        0.010174
# name         runtime        0.010392
# runtime      name           0.010392
# name         year           0.011453
# year         name           0.011453
# star         company        0.012442
# company      star           0.012442
# yearcorrect  name           0.012835
# name         yearcorrect    0.012835
#              votes          0.013088
# votes        name           0.013088
# rating       star           0.013405
# star         rating         0.013405
# country      writer         0.015343
# writer       country        0.015343
# name         genre          0.016355
# genre        name           0.016355
# name         score          0.017097
# score        name           0.017097
# country      director       0.017490
# director     country        0.017490
#              runtime        0.017624
# runtime      director       0.017624
# score        writer         0.019416
# writer       score          0.019416
# rating       director       0.019483
# director     rating         0.019483
# budget       name           0.023970
# name         budget         0.023970
# star         writer         0.027245
# writer       star           0.027245
# score        genre          0.027965
# genre        score          0.027965
# votes        rating         0.033225
# rating       votes          0.033225
# runtime      company        0.034402
# company      runtime        0.034402
# star         director       0.039234
# director     star           0.039234
# budget       country        0.054063
# country      budget         0.054063
# runtime      rating         0.062145
# rating       runtime        0.062145
# genre        rating         0.072423
# rating       genre          0.072423
# votes        country        0.073625
# country      votes          0.073625
# budget       score          0.076254
# score        budget         0.076254
# rating       country        0.081244
# country      rating         0.081244
# gross        country        0.092129
# country      gross          0.092129
#              company        0.095548
# company      country        0.095548
# year         score          0.097995
# score        year           0.097995
#              yearcorrect    0.107219
# yearcorrect  score          0.107219
# runtime      yearcorrect    0.115317
# yearcorrect  runtime        0.115317
# runtime      year           0.120811
# year         runtime        0.120811
# company      votes          0.133204
# votes        company        0.133204
# company      gross          0.154840
# gross        company        0.154840
# company      budget         0.173214
# budget       company        0.173214
# score        gross          0.186258
# gross        score          0.186258
# yearcorrect  votes          0.206475
# votes        yearcorrect    0.206475
# year         votes          0.222945
# votes        year           0.222945
# gross        yearcorrect    0.240651
# yearcorrect  gross          0.240651
# gross        runtime        0.245216
# runtime      gross          0.245216
# gross        year           0.257486
# year         gross          0.257486
# director     writer         0.299067
# writer       director       0.299067
# runtime      votes          0.309212
# votes        runtime        0.309212
# budget       yearcorrect    0.315348
# yearcorrect  budget         0.315348
# runtime      budget         0.320447
# budget       runtime        0.320447
#              year           0.329321
# year         budget         0.329321
# score        runtime        0.399451
# runtime      score          0.399451
# score        votes          0.409182
# votes        score          0.409182
#              budget         0.442429
# budget       votes          0.442429
# votes        gross          0.630757
# gross        votes          0.630757
#              budget         0.740395
# budget       gross          0.740395
# yearcorrect  year           0.967486
# year         yearcorrect    0.967486
# name         name           1.000000
# writer       writer         1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs)>0.5]
high_corr
# Out:
# votes        gross          0.630757
# gross        votes          0.630757
#              budget         0.740395
# budget       gross          0.740395
# yearcorrect  year           0.967486
# year         yearcorrect    0.967486
# name         name           1.000000
# writer       writer         1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
#votes and budget have the highest correlation to gross earnings
